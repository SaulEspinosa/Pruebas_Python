# %% [markdown]
# ## Pruebas 1

# %%
import random 
import matplotlib.pyplot as plt

x = [random.randrange(0,100) for i in range(100)]
y = [random.randrange(0,100) for i in range(100)]

plt.bar(x,y)
plt.show()
